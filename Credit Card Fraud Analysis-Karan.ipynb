# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# No Null Values

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %% [markdown]
# EDA

# %%
data.duplicated().any()
# Out:
# True

# %% [markdown]
# Duplicate Transactions are part of the data

# %%
newdata=data.drop_duplicates()

# %%
newdata.shape
# Out:
# (283726, 31)

# %%
newdata.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
newdata.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
newdata["Class"].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %% [markdown]
# 0 - Successful Transactions
# 1- Fraudulent Transactions

# %%
successful_transactions = newdata[newdata['Class']==0]
fraudulent_transactions = newdata[newdata['Class']==1]

# %%
successful_transactions
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraudulent_transactions
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
newdata["Class"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
ft=fraudulent_transactions['Amount'].sum()
ft
# Out:
# 58591.39

# %%
st=successful_transactions["Amount"].sum()
st
# Out:
# 25043410.289999995

# %%
print("Loss due to fraudulent transaction = ",st-ft)
# Out:
# Loss due to fraudulent transaction =  24984818.899999995

# %%
stn=successful_transactions["Class"].count()
stn
# Out:
# 283253

# %%
ftn=fraudulent_transactions["Class"].count()
ftn
# Out:
# 473

# %%
tt=data["Class"].count()
tt
# Out:
# 284807

# %%
print("Percentage of Successful Transaction = ",(stn/tt)*100)
# Out:
# Percentage of Successful Transaction =  99.45436734349929

# %%
print("Percentage of Fraudulent Transaction = ",(ftn/tt)*100)
# Out:
# Percentage of Fraudulent Transaction =  0.16607737871611303

# %%
newdata
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
newdata.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
newdata.hist(figsize=(20,20))
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(newdata.index,newdata["Time"])
plt.xlabel("Transaction")
plt.ylabel("Time")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(newdata.index,newdata["Amount"])
plt.xlabel("Transaction")
plt.ylabel("Amount")
plt.title("Amount over transactions")
plt.show()

# %% [markdown]
# Correlation Of Unbalanced Data

# %%
correlation_matrix=newdata.corr()
k=correlation_matrix["Class"].sort_values(ascending=False)
print(k)
# Out:
# Class     1.000000
# V11       0.149067
# V4        0.129326
# V2        0.084624
# V19       0.033631
# V8        0.033068
# V21       0.026357
# V27       0.021892
# V20       0.021486
# V28       0.009682
# Amount    0.005777
# V22       0.004887
# V26       0.004265
# V25       0.003202
# V15      -0.003300
# V13      -0.003897
# V23      -0.006333
# V24      -0.007210
# Time     -0.012359
# V6       -0.043915
# V5       -0.087812
# V9       -0.094021
# V1       -0.094486
# V18      -0.105340
# V7       -0.172347
# V3       -0.182322
# V16      -0.187186
# V10      -0.206971
# V12      -0.250711
# V14      -0.293375
# V17      -0.313498
# Name: Class, dtype: float64

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %% [markdown]
# Balancing the dataset

# %%
X = newdata.drop('Class', axis=1)
Y = newdata['Class']

# %%
X.shape
# Out:
# (283726, 30)

# %%
Y.shape
# Out:
# (283726,)

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score,precision_score

# %%
smote = SMOTE(random_state=42) 
x_smote, y_smote = smote.fit_resample(X, Y)

# %%
y_smote.value_counts()
# Out:
# 0    283253
# 1    283253
# Name: Class, dtype: int64

# %%
corr_balanced = x_smote.corr()

# %%
sns.heatmap(corr_balanced)
# Out:
# <Axes: >

# %%
x_smote
# Out:
#                  Time        V1        V2         V3        V4        V5  \
# 0            0.000000 -1.359807 -0.072781   2.536347  1.378155 -0.338321
# 1            0.000000  1.191857  0.266151   0.166480  0.448154  0.060018
# 2            1.000000 -1.358354 -1.340163   1.773209  0.379780 -0.503198
# 3            1.000000 -0.966272 -0.185226   1.792993 -0.863291 -0.010309
# 4            2.000000 -1.158233  0.877737   1.548718  0.403034 -0.407193
# ...               ...       ...       ...        ...       ...       ...
# 566501   41183.445750 -7.151786  5.337862 -10.524210  6.638176 -7.107253
# 566502   14264.057012 -4.705909  8.250299 -14.559164  9.787990 -4.117161
# 566503  135064.971368  0.407366  1.352354  -4.892782  3.554728 -1.282114
# 566504  109361.849259  0.580032  2.773047  -5.790024  5.606953  0.398480
# 566505   84438.552579 -2.819178  2.410529  -5.833727  4.099991 -2.622497
#
#               V6         V7        V8        V9  ...       V20       V21  \
# ...

# %%
fraud_transaction = newdata[newdata['Class'] == 0]
real_transaction = newdata[newdata['Class'] == 1]
plt.figure(figsize=(20, 20))
plt.xlim(0, 6000)
plt.ylim(0, 5000)
plt.title("Fraud vs. Real Transactions")
plt.xlabel("Amount")
plt.ylabel("Frequency")
sns.histplot(fraud_transaction['Amount'],label="Fraud")
sns.histplot(real_transaction['Amount'],label="Real")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 20))
plt.title("Transaction Amount")
sns.boxplot(x="Class", y="Amount", data=newdata)
plt.show()

# %% [markdown]
# Logistic Regression Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_smote, y_smote, test_size=0.20, random_state=42)

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_lr = lr.predict(X_test)

accuracy = accuracy_score(Y_test, y_pred_lr)
confusion = confusion_matrix(Y_test, y_pred_lr)


print(f"Accuracy Score of Logistic Regression is : {accuracy}")
print(f"Confusion Matrix : \n{confusion}")
# Out:
# Accuracy Score of Logistic Regression is : 0.9702564826746218
# Confusion Matrix :
# [[55210  1253]
#  [ 2117 54722]]

# %%
X_train=pd.DataFrame(X_train)

# %%
num_cols=X_train._get_numeric_data().columns

# %%
X_train[num_cols].hist()
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>],
#        [<Axes: title={'center': 'V5'}>, <Axes: title={'center': 'V6'}>,
#         <Axes: title={'center': 'V7'}>, <Axes: title={'center': 'V8'}>,
#         <Axes: title={'center': 'V9'}>],
#        [<Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>,
#         <Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>],
#        [<Axes: title={'center': 'V15'}>, <Axes: title={'center': 'V16'}>,
#         <Axes: title={'center': 'V17'}>, <Axes: title={'center': 'V18'}>,
#         <Axes: title={'center': 'V19'}>],
#        [<Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>,
#         <Axes: title={'center': 'V24'}>],
# ...

# %%
confusion_matrix_logistic = confusion_matrix(Y_test, y_pred_lr)
classification_report_logistic = classification_report(Y_test, y_pred_lr, output_dict=True)

confusion_matrix_df = pd.DataFrame(confusion_matrix_logistic, 
                                   columns=["Predicted Negative (0)", "Predicted Positive (1)"],
                                   index=["Actual Negative (0)", "Actual Positive (1)"])

classification_report_df = pd.DataFrame(classification_report_logistic)

print("Logistic Regression Model - Confusion Matrix:")
print(confusion_matrix_df)

print("\nLogistic Regression Model - Classification Report:")
print(classification_report_df)
# Out:
# Logistic Regression Model - Confusion Matrix:
#                      Predicted Negative (0)  Predicted Positive (1)
# Actual Negative (0)                   55210                    1253
# Actual Positive (1)                    2117                   54722
#
# Logistic Regression Model - Classification Report:
#                       0             1  accuracy      macro avg   weighted avg
# precision      0.963072      0.977615  0.970256       0.970343       0.970367
# recall         0.977808      0.962754  0.970256       0.970281       0.970256
# f1-score       0.970384      0.970128  0.970256       0.970256       0.970256
# support    56463.000000  56839.000000  0.970256  113302.000000  113302.000000

# %% [markdown]
# Hyperparameter Boosting Using XGBoost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(max_depth=13,n_estimators=300,learning_rate=0.5)

xgb.fit(X_train, Y_train)

y_pred_xgbc = xgb.predict(X_test)

# %%
precision_score_xgb =  precision_score(Y_test, y_pred_xgbc)
accuracy_score_xgb = accuracy_score(Y_test, y_pred_xgbc)
print('The precision score  is = ',(precision_score_xgb * 100), '%')
print('The accuracy score is = ',(accuracy_score_xgb * 100), '%')
print (classification_report(Y_test,y_pred_xgbc))
# Out:
# The precision score  is =  99.96658283061012 %
# The accuracy score is =  99.98234806093448 %
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56463
#            1       1.00      1.00      1.00     56839
#
#     accuracy                           1.00    113302
#    macro avg       1.00      1.00      1.00    113302
# weighted avg       1.00      1.00      1.00    113302

# %% [markdown]
# Decision Tree - Model Validation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train, Y_train)

y_pred_dtc = dtc.predict(X_test)

acc_dtc = accuracy_score(Y_test, y_pred_dtc)
conf = confusion_matrix(Y_test, y_pred_dtc)
clf_report = classification_report(Y_test, y_pred_dtc)

print(f"Accuracy Score of Decision Tree is : {acc_dtc}")
print(f"Confusion Matrix : \n{conf}")
print(f"Classification Report : \n{clf_report}")
# Out:
# Accuracy Score of Decision Tree is : 0.9987378863568163
# Confusion Matrix :
# [[56357   106]
#  [   37 56802]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56463
#            1       1.00      1.00      1.00     56839
#
#     accuracy                           1.00    113302
#    macro avg       1.00      1.00      1.00    113302
# weighted avg       1.00      1.00      1.00    113302

# %% [markdown]
# The above analysis shows the dataset is accuarate upto 99% ~100%

# %% [markdown]
# This helps us know the effectiveness of measures taken to tackle fraudulent activities thereby efficiency of the cybersecurity team
